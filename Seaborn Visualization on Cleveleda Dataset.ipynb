# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r'D:\bepec\Datasets\clevelanda.csv')
data.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
data.describe()
# Out:
#               age      gender          cp    trestbps        chol         fps  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope       class
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.937294
# ...

# %%
data.shape
# Out:
# (303, 14)

# %%
data.age.unique()
# Out:
# array([63, 67, 37, 41, 56, 62, 57, 53, 44, 52, 48, 54, 49, 64, 58, 60, 50,
#        66, 43, 40, 69, 59, 42, 55, 61, 65, 71, 51, 46, 45, 39, 68, 47, 34,
#        35, 29, 70, 77, 38, 74, 76], dtype=int64)

# %%
data.age.value_counts()
# Out:
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 60    12
# 51    12
# 56    11
# 62    11
# 44    11
# 64    10
# 41    10
# 67     9
# 63     9
# 42     8
# 43     8
# 45     8
# 53     8
# 55     8
# 61     8
# 65     8
# 50     7
# 66     7
# 48     7
# 46     7
# 47     5
# 49     5
# 70     4
# 68     4
# 35     4
# 39     4
# 69     3
# 71     3
# 40     3
# 34     2
# 37     2
# 38     2
# 29     1
# 77     1
# 74     1
# 76     1
# Name: age, dtype: int64

# %% [markdown]
# <b>Majority of the people are senior citizens and very few of them are young.</b>

# %%
data['class'].value_counts()
# Out:
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: class, dtype: int64

# %% [markdown]
# <b>164 people are not having the disease while 13 people have disease with extreme risk intensity of heart attack.</b>

# %% [markdown]
# <b><h3><font color='gray'> Understanding Data Attributes </font></h3></b><br><br>
# <b>age</b> - patient's age <br><br>
# <b>gender</b>  - Male : <b>1</b>, Female : <b>0</b><br><br>
# <b>cp</b> - cp: chest pain type <br>
# -- Value 1: typical angina - Angina is a type of chest pain caused by reduced blood flow to the heart. <br>
# -- Value 2: atypical angina - Angina chest pain is a pressure or squeezing like sensation that is usually caused when your   heart muscle doesn't get an adequate supply of oxygenated blood. <br>
# -- Value 3: non-anginal pain - Chest pain that is relieved after more than 10 minutes is either not angina or unstable angina. <br>
# -- Value 4: asymptomatic - described as "silent" because when they occur, their symptoms lack the intensity of a classic heart attack, such as extreme chest pain and pressure <br><br>
# <b>trestbps </b> - resting blood pressure (in mm Hg on admission to the hospital) <br>
# Normal blood pressure for most adults is defined as a systolic pressure of less than 120 <br> and a diastolic pressure of less than 80.<br> Elevated blood pressure is defined as a systolic pressure between 120 and 129 with a diastolic pressure of less than 80. <br><br>
# <b>chol</b> - serum cholestoral in mg/dl <br>
# What happens if serum cholesterol is high? <br>
# Your body needs cholesterol to build healthy cells <br>  but high levels of cholesterol can increase your risk of heart disease. <br>  With high cholesterol, you can develop fatty deposits in your blood vessels. <br>  Eventually, these deposits grow, making it difficult for enough blood to flow through your arteries.<br><br>
# <b>fps</b> - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false) <br>
# This measures your blood sugar after an overnight fast (not eating). <br> A fasting blood sugar level of 99 mg/dL or lower is normal <br> 100 to 125 mg/dL indicates you have prediabetes <br> and 126 mg/dL or higher indicates you have diabetes.<br><br>
# <b>restecg</b> - resting electrocardiographic results <br>
# -- Value 0: normal <br>
# -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV) <br>
# -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria <br><br>
# <p>Results: In 590 patients with no previous history of a myocardial infarction and entirely normal resting electrocardiographic results without nonspecific ST-T wave abnormalities, the mean left ventricular ejection fraction was 0.63 +/- 0.004, and 559 patients (95%) had a normal resting ejection fraction (defined as 0.50 or more). Both nonspecific ST-T wave abnormalities (p less than 0.001) and, to a lesser degree, a history of myocardial infarction (p = 0.06) were independent predictors of an abnormal resting ejection fraction. In 185 patients with nonspecific ST-T wave abnormalities and no history of myocardial infarction, the mean left ventricular ejection fraction was 0.61 +/- 0.009, and 85% had a normal resting ejection fraction. In 36 patients with nonspecific ST-T wave abnormalities and a history of myocardial infarction, the mean left ventricular ejection fraction was 0.53 +/- 0.021, and 72% had a normal resting ejection fraction.
#
# Conclusion: Thus, an entirely normal result on a resting 12-lead electrocardiogram in patients with suspected coronary disease but no history of a previous myocardial infarction is a reliable (95%) predictor of normal left ventricular function. If nonspecific ST-T wave abnormalities are noted, particularly if there is a history of a previous infarction, the predictive value of the electrocardiographic findings is diminished.</p><br><br>
#
# <b>thalach</b> - maximum heart rate achieved <br>
# You can calculate your maximum heart rate by subtracting your age from 220.<br> For example, if you're 45 years old, subtract 45 from 220 to get a maximum heart rate of 175.<br> This is the average maximum number of times your heart should beat per minute during exercise.<br><br>
# <b>exang</b> - exercise induced angina (1 = yes; 0 = no) <br>
# <p>Angina (pronounced ANN-juh-nuh or ann-JIE-nuh) is pain in the chest that comes on with exercise, stress, or other things that make the heart work harder. It is an extremely common symptom of coronary artery disease, which is caused by cholesterol-clogged coronary arteries.</p><br>
# Stable angina is usually triggered by physical activity.<br>When you climb stairs, exercise or walk, your heart demands more blood, but narrowed arteries slow down blood flow.<br><br>
# <b>oldpeak</b> - ST depression induced by exercise relative to rest <br>
# <p>Exercise induced ST segment depression is considered a reliable ECG finding for the diagnosis of obstructive coronary atherosclerosis. It has also been associated with a worse prognosis for patients with a documented coronary artery disease (CAD)</p><br><br>
# <b>slope</b> - the slope of the peak exercise ST segment <br>
# -- Value 1: upsloping <br>
# Upsloping ST depression in resting electrocardiogram may indicate cardiac ischemia in the presence of active cardiac symptoms.<br>
# -- Value 2: flat <br>
# <p>Because of the long duration of the plateau phase most contractile cells are in this phase at the same time (more or less). Moreover, the membrane potential is relatively unchanged during the plateau phase. These two factors are the reason why the ST segment is flat and isoelectric (i.e in level with the baseline).</p><br>
# -- Value 3: downsloping <br>
# <p>Although greater downsloping ST-segment depression is suspected to indicate more severe ischemia, its exact relationship to regional myocardial blood flow (RMBF) has not yet been clarified.</p><br><br>
# <p>Myocardial ischemia occurs when blood flow to your heart is reduced, preventing the heart muscle from receiving enough oxygen. The reduced blood flow is usually the result of a partial or complete blockage of your heart's arteries (coronary arteries).</p><br><br>
# <b>ca</b> - number of major vessels (0-3) colored by flourosopy <br>
# <p>The major blood vessels connected to your heart are the aorta, the superior vena cava, the inferior vena cava, the pulmonary artery (which takes oxygen-poor blood from the heart to the lungs where it is oxygenated), the pulmonary veins (which bring oxygen-rich blood from the lungs to the heart), and the coronary arteries (which supply blood to the heart muscle).</p><br><br>
# <b>thal</b> - 3 = normal; 6 = fixed defect; 7 = reversable defect <br>
# <p>‌The thallium stress test is an imaging study that shows your doctor how well blood flows to your heart. It measures your blood flow during rest and after exercise. The thallium stress test is also called a nuclear stress test, a treadmill test, a stress perfusion test, or a cardiac SPECT.</p><br>
# <p>the size of your heart chambers
# how effectively your heart pumps —that is, its ventricular function
# how well your coronary arteries supply your heart with blood, known as myocardial perfusion
# if your heart muscle is damaged or scarred from previous heart attacks</p><br><br>
# <p>Your doctor may order a thallium test for a variety of reasons, including:
#
# if they suspect your heart isn’t getting enough blood flow when it’s under stress — for example, when you exercise
# if you have chest pain or worsening angina
# if you’ve had a previous heart attack
# to check how well medications are working
# to determine whether a procedure or surgery was successful
# to determine whether your heart is healthy enough to start an exercise program</p><br><br>
# <b>class</b> - values = 0,1,2,3,4<br>
# 0 represents there is no heart disease and 1,2,3,4 represent presence of heart disease with the level of intensity.

# %% [markdown]
# <h2><font color='#47D9E1 '> UNIVARIATE, BIVARIATE AND MULTIVARIATE ANALYSIS </font></h2>

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))
fig.suptitle('2 x 3 axes histplot with continuous data')
 
sns.histplot(ax=axes[0, 0], data=data['age'], kde = True, color = 'black')
sns.histplot(ax=axes[0, 1], data=data['chol'], kde = True, color = 'black')
sns.histplot(ax=axes[1, 0], data=data['trestbps'], kde = True, color = 'black')
sns.histplot(ax=axes[1, 1], data=data['thalach'], kde = True, color = 'black')
plt.show()

# %%
sns.displot(data['oldpeak'], kde = True)

# %%
sns.set_theme(style="ticks")
sns.countplot(data=data, x="class")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 10))
fig.suptitle('3 x 3 axes countplot of categorical data')
sns.set_theme(style="ticks") 
sns.countplot(ax=axes[0, 0], data=data, x="gender")
sns.countplot(ax=axes[0, 1], data=data, x="cp")
sns.countplot(ax=axes[0, 2], data=data, x="fps")
sns.countplot(ax=axes[1, 0], data=data, x="restecg")
sns.countplot(ax=axes[1, 1], data=data, x="exang")
sns.countplot(ax=axes[1, 2], data=data, x="slope")
sns.countplot(ax=axes[2, 0], data=data, x="ca")
sns.countplot(ax=axes[2, 1], data=data, x="thal")
sns.countplot(ax=axes[2, 2], data=data, x="class")

plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('2 x 3 axes countplot to compare counts w.r.t. gender')
sns.set_theme(style="ticks") 
sns.countplot(ax=axes[0, 0], data=data, x="class", hue="gender")
sns.countplot(ax=axes[0, 1], data=data, x="cp", hue="gender")
sns.countplot(ax=axes[0, 2], data=data, x="fps", hue="gender")
sns.countplot(ax=axes[1, 0], data=data, x="restecg", hue="gender")
sns.countplot(ax=axes[1, 1], data=data, x="exang", hue="gender")
sns.countplot(ax=axes[1, 2], data=data, x="slope", hue="gender")
plt.show()

# %%
sns.countplot(x="class", data=data,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
g = sns.catplot(x="gender", hue="fps", col="class",
                data=data, kind="count",
                height=4, aspect=.7);

# %%
data['chol'].loc[data['class']==0]
# Out:
# 0      233
# 3      250
# 4      204
# 5      236
# 7      354
#       ...
# 288    221
# 289    240
# 291    342
# 295    157
# 302    175
# Name: chol, Length: 164, dtype: int64

# %%
plt.figure(figsize=(9,5))
country = [data['chol'].loc[data['class']==0].sum(),data['chol'].loc[data['class']==1].sum(),
          data['chol'].loc[data['class']==2].sum(),data['chol'].loc[data['class']==3].sum(),
          data['chol'].loc[data['class']==4].sum()]
colors = sns.color_palette('bright')
plt.pie(country, labels= data['class'].unique(), colors = colors)
plt.tight_layout()
plt.title('Cholesterol measure w.r.t. class')
plt.legend(loc=3)
plt.show()

# %%
sns.pairplot(data)

# %%
a = sns.FacetGrid(data, col = 'class')
a.map(plt.hist, 'age', color = 'cyan')

# %%
sns.kdeplot(data = data, x = 'thalach', hue = 'gender', multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='Density'>

# %%
sns.kdeplot(data = data, x = 'age', hue = 'cp', multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data = data, x = 'chol', hue = 'class', multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='chol', ylabel='Density'>

# %%
sns.scatterplot(data = data, x = 'trestbps', y = 'oldpeak', size = 'slope')
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='oldpeak'>

# %%
sns.scatterplot(data = data, x = 'chol', y = 'ca', size = 'class')
# Out:
# <AxesSubplot:xlabel='chol', ylabel='ca'>

# %%
sns.scatterplot(data = data, x = 'cp', y = 'age', size = 'class', color = 'black')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %%
sns.scatterplot(data = data, x = 'trestbps', y = 'oldpeak', size = 'cp', style = 'class')
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='oldpeak'>

# %%
sns.relplot(data = data, x = 'thalach', y = 'age', hue = 'slope')

# %%
sns.relplot(data = data, x = 'trestbps', y = 'chol', hue = 'slope', col = 'class')

# %%
sns.relplot(data = data, x = 'chol', y = 'age', hue = 'cp', col = 'gender', row = 'exang', kind = 'scatter')

# %%
sns.relplot(data = data, x = 'age', y = 'thalach', hue = 'cp', col = 'exang', row = 'slope', kind = 'scatter')

# %%
sns.relplot(data = data, x = 'age', y = 'chol', hue = 'gender', kind = 'line')

# %% [markdown]
# <b>From above plot we can see that, as age increases cholesterol increases a little by little</b>

# %%
sns.scatterplot(data = data, x = 'cp', y = 'age', size = 'cp')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %% [markdown]
# <b> As we can see that chest pain has no dependency on age means it's not necessary that chest pain will be caused to only aged people mostly</b>

# %%
sns.scatterplot(data = data, x = 'thalach', y = 'oldpeak', size = 'class')
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='oldpeak'>

# %% [markdown]
# <b>From above scatter plot we find the main thing about exercising is that,<br>
#     a person having more thalach and oldpeak less than 1 is not having any heart disease.<br>
#     In other hand, people having more oldpeaks and midrange thalach have critical level of heart disease.</b>

# %%
sns.scatterplot(data = data, x = 'slope', y = 'oldpeak', size = 'cp')
# Out:
# <AxesSubplot:xlabel='slope', ylabel='oldpeak'>

# %%
sns.scatterplot(data = data, x = 'ca', y = 'age', size = 'class')
# Out:
# <AxesSubplot:xlabel='ca', ylabel='age'>

# %%
sns.scatterplot(size = 'class', data = data, x = 'cp', y = 'oldpeak')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='oldpeak'>

# %% [markdown]
# <b>From above graph it is seen that the people who are having 2 or more than 2 major blood vessels, they<br>
#     have the intense heart disease and can suffer heart attack.</b>

# %%
sns.jointplot(data = data, x = 'thalach', y = 'age')

# %%
sns.jointplot(data = data, x = 'age', y = 'trestbps', color = 'red', kind = 'kde')

# %%
sns.boxenplot(data = data, x = 'gender', y = 'chol')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='chol'>

# %%
sns.boxenplot(data = data, x = 'ca', y = 'thalach')
# Out:
# <AxesSubplot:xlabel='ca', ylabel='thalach'>

# %%
sns.boxenplot(data = data, x = 'cp', y = 'trestbps')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='trestbps'>

# %%
sns.violinplot(data = data, x = 'gender', y = 'class')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='class'>

# %%
sns.violinplot(data = data, x = 'class', y = 'chol')
# Out:
# <AxesSubplot:xlabel='class', ylabel='chol'>

# %%
sns.violinplot(data = data, x = 'slope', y = 'thalach')
# Out:
# <AxesSubplot:xlabel='slope', ylabel='thalach'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data = data.corr(), annot = True, cmap = 'Dark2')
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data=data, x="age", y="chol")
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
sns.lineplot(data=data, x="age", y="thalach", color = 'lime') # increase in age decrease in talach
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %% [markdown]
# <h4><b><p>From above graph we see that when a person gets older the maximum heart rate achieved is lesser by the time.<br>
# May be as a person grows older his muscles and body gets weaker and so he/she is not able to do more workout or exercise.<br>
# As young people are very active so they do intense workout but older peole don't do exercise much or they do light workout which is why there is not much higher heart rate during exercise as we grow older.</p></b></h4>

# %%
sns.lineplot(data=data, x="age", y="oldpeak", color = 'black')
# Out:
# <AxesSubplot:xlabel='age', ylabel='oldpeak'>

# %%
sns.lineplot(data=data, x="age", y="thalach", hue="exang")
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %%
sns.lineplot(data=data, x="slope", y="oldpeak", hue="cp")
# Out:
# <AxesSubplot:xlabel='slope', ylabel='oldpeak'>

# %%
sns.barplot(data = data, x = 'class', y = 'age', )
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.barplot(data = data, x = 'class', y = 'chol', estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='class', ylabel='chol'>

# %%
sns.barplot(data = data, x = 'cp', y = 'oldpeak', estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='oldpeak'>

# %% [markdown]
# <b><p>People having chest pain 1 and 4 i.e. typical angina and asymptomatic chest pain/extreme chest pain have more oldpeak i.e. the point of inflection at the junction of the S wave and ST segment becomes depressed during exercise, with maximum depression at peak exercise. So these people must be careful as cardiac arrest can be caused.</p></b>

# %% [markdown]
# <font color='#F16C20'><h2>Conclusion</h2><br></font>
# <font color='#F16C20'><h3>Important points/insights drawn from the visualization : </h3><br></font>
# <font color='#5F5F5F'><b><ol><li>The major takeaway from this data visualization is that, heart disease is just not majorly correlated with or strongly dependent on any one or two attributes. </li>
#     <li>Like if cholesterol is more then there are more chances of heart disease or if age is less with less thalach then heart disease won't happen, is not seen here. Because every single attribute is almost equally important and responsible for the heart disease with highest weightage.</li>
#     <li>But surely there are few attributes which do have impact on each others like if age increases then cholesterol increases and a person's energy decreases by which talach reduces gradually as age increases.</li>
#     <li>Still these attributes are not making very much impact on our target attribute but togetherly all these attributes combined are making an impact on our target which is heart disease i.e. class.</li></ol></b></font>
